# %% [markdown]
# # Datenanalyse: "YouTube Trends in Deutschland"
# - das ist wichtig bei jedem Data Science Projekt
# - zuerst schaut man sich die Daten einmal gründlich an, um daraus Erkenntnisse zu gewinnen
# - bspw. Trends und Muster, Ausreißer und interessante Zusammenhänge
#
# Welche Daten sind das:
# Es handelt sich hierbei um selbst gesammelte YouTube Daten.

# %% [markdown]
# ## Vorbereitungsteil
# ### 1. Python Bibliotheken importieren
# - Bibliotheken müssen vorher via pip oder conda installiert werden, bevor man sie importieren kann
# - Wir Nutzen Pandas als Bibliothek für Datenanalyse
# - matplotlib und seaborn für Visualisierungen
#
# ### <span style="color:red">Wir installieren diese mit pip via Terminal:</span>
# - `pip install pandas`
# - `pip install matplotlib`
# - `pip install seaborn`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Daten laden (parquet-Format)
# - Oft sind die Daten im CSV oder JSON Format
# - Wir haben diesmal aber Daten im Parquet Format bekommen, also benötigen wir diese Funktion um sie lesen zu können
#     - das Parquet Dateiformat ist übrigens auch effizienter als CSV oder JSON.
#
# ### <span style="color:red">Für das Parquet Format braucht Pandas oft nochmal eine Extrabibliothek! <i>pyarrow</i>:</span>
#
# `pip install pyarrow`</mark>

# %%
# Daten mittels Pandas einlesen
youtube_data = pd.read_parquet('youtube_trend_videos.parquet')
youtube_data.head(10)
# Out:
#            _id               created          published_at  \
# 0  QKWE-jtCI6A  2021-04-05T20:29:34Z  2021-04-04T11:14:13Z
# 1  omZDa8BRmjs  2021-04-05T20:29:34Z  2021-04-04T17:00:28Z
# 2  2XOFLRPnFC0  2021-04-05T20:29:34Z  2021-04-03T13:00:14Z
# 3  yyNBca9vYtw  2021-04-05T20:29:34Z  2021-04-04T18:00:19Z
# 4  6vrlsYoPT2U  2021-04-05T20:29:34Z  2021-04-04T11:23:07Z
# 5  epxBlEGItM4  2021-04-05T20:29:34Z  2021-04-03T22:17:12Z
# 6  va_dglw8qJI  2021-04-05T20:29:34Z  2021-04-04T10:01:05Z
# 7  61PVs2N61H0  2021-04-05T20:29:34Z  2021-04-04T21:57:24Z
# 8  5hdKcitAcqs  2021-04-05T20:29:34Z  2021-04-04T10:00:01Z
# 9  6r0_Vqmuwvo  2021-04-05T20:29:34Z  2021-04-03T18:58:05Z
#
#             modified_at                          channel  \
# 0  2021-04-05T20:58:14Z                         Dagi Bee
# 1  2021-04-05T20:58:14Z                              Gnu
# 2  2021-04-06T22:37:06Z                      Brawl Stars
# 3  2021-04-05T20:58:14Z                        laserluca
# 4  2021-04-05T20:58:14Z                    Fynn Kliemann
# 5  2021-04-05T20:58:14Z  Deutschland sucht den Superstar
# 6  2021-04-05T20:58:14Z                       Bulien Jam
# 7  2021-04-09T01:15:06Z                      Technoblade
# 8  2021-04-05T20:58:14Z              Felix von der Laden
# 9  2021-04-05T20:58:14Z                  ELoTRiX - Clips
#
#                  channel_id  \
# 0  UCpZ_DI-ZugwMzXcqccaTVsg
# 1  UC0m40b5CPcB801gVEz25WuQ
# 2  UCooVYzDxdwTtGYAkcPmOgOw
# 3  UCmxc6kXbU1J-0pR2F3wIx9A
# 4  UCa_MF1hIC-oCTsEJDegmaIQ
# 5  UC6jGqtmHfNQiwKFxH__-rfA
# 6  UCNpP_PH0Uj8Ldc7INQ-ih_Q
# 7  UCFAiFyGs6oDiF1Nf-rRJpZA
# 8  UChr1sKJ27Fr6WZxAlusbo_w
# 9  UCMPROZGfCUp7vlVFS-nBF_A
#
#                                                 rank  \
# 0                                                [1]
# 1                                                [2]
# 2  [3, 15, 3, 16, 21, 22, 27, 28, 30, 33, 34, 31,...
# 3                                             [4, 5]
# 4                                             [5, 4]
# 5                                                [6]
# 6                                                [7]
# 7  [8, 1, 8, 1, 2, 3, 4, 5, 6, 7, 8, 9, 8, 9, 17,...
# 8                                                [9]
# 9                                               [10]
#
#                                                title  \
# 0  [Ich habe mir 4 Tattoos gestochen ( Po & Hals ...
# 1  [Üble GERÜCHTE über Anni und Gnu! Jetzt reicht...
# 2  [Brawl Stars: Brawl Talk! Two New Brawlers, TO...
# 3                             [ICH WERDE ÜBERFALLEN]
# 4       [Sowas wie n VLOG oderso #3 | Pic & Abfahrt]
# 5  [Jan-Marten Block mit "Never Not Try" | DSDS 2...
# 6  [Meine ROOMTOUR 2021 vs 2017 - Viel hat sich v...
# 7        [I Must Win MrBeast's $10,000 Refrigerator]
# 8                                   [Es ist vorbei!]
# 9  [ROLEX von UNSYMPATHISCHTV GESCHENKT BEKOMMEN ...
#
#                                                 tags  category  ...  \
# 0  [[dagibee, dagi, daggi, daggy, beetique, dagi ...        26  ...
# 1  [[Saftiges Gnu, Saftigesgnu, gnumama, gnu, gnu...        24  ...
# 2  [[brawl stars, mobile game, mobile strategy ga...        20  ...
# 3                                             [None]        24  ...
# 4                                             [None]        24  ...
# 5  [[DSDS, RTLDSDS2012, Superstar, Deutschland su...        24  ...
# 6  [[Bulien Jam, Julien Bam, Roomtour, bulien Roo...        24  ...
# 7  [[Minecraft, Technoblade, Technothepig, Hypixel]]        20  ...
# 8  [[felixladen, dner, spielkind, vlog, 2020, Fel...        19  ...
# 9  [[elotrix, reactions, clips, elotrix clips, tw...        20  ...
#
#                                                likes  \
# 0                                 [16530.0, 16675.0]
# 1                                 [32424.0, 32633.0]
# 2  [921487.0, 922107.0, 922207.0, 922355.0, 92237...
# 3                                 [52836.0, 53118.0]
# 4                                 [13534.0, 13596.0]
# 5                                 [13486.0, 13556.0]
# 6                                 [37910.0, 38159.0]
# 7  [429127.0, 431875.0, 432451.0, 433104.0, 43321...
# 8                                 [19222.0, 19310.0]
# 9                                 [16739.0, 16823.0]
#
#                                             dislikes  \
# 0                                     [745.0, 777.0]
# 1                                     [502.0, 519.0]
# 2  [10917.0, 10942.0, 10947.0, 10954.0, 10955.0, ...
# 3                                     [578.0, 590.0]
# 4                                             [81.0]
# 5                                   [1451.0, 1459.0]
# 6                                     [344.0, 345.0]
# 7  [1265.0, 1313.0, 1318.0, 1334.0, 1337.0, 1338....
# 8                                     [584.0, 590.0]
# 9                                     [158.0, 159.0]
#
#                                             comments  \
# 0                                     [423.0, 436.0]
# 1                                   [1553.0, 1564.0]
# 2  [114045.0, 114051.0, 114060.0, 114075.0, 11407...
# 3                                   [9926.0, 9963.0]
# 4                                            [283.0]
# 5                                   [1564.0, 1566.0]
# 6                                   [1534.0, 1543.0]
# 7  [24932.0, 25006.0, 25015.0, 25032.0, 25029.0, ...
# 8                                            [578.0]
# 9                                            [494.0]
#
#                                                views duration  audio_language  \
# 0                                   [375799, 382556]     1062              de
# 1                                   [297064, 302078]      889              de
# 2  [17746044, 17834813, 17852404, 17866972, 17881...      255              en
# 3                                   [422027, 427309]      879              de
# 4                                   [172193, 174353]      348              de
# 5                                   [743066, 749139]      208              de
# 6                                   [394853, 398872]      856              de
# 7  [2951569, 3008056, 3018330, 3029688, 3031183, ...      788              en
# 8                                   [251052, 253470]      553              de
# 9                                   [218433, 220157]      238           de-DE
#
#   text_language caption  licensed_content   projection
# 0          None   False              True  rectangular
# 1          None   False              True  rectangular
# 2            en    True              True  rectangular
# 3            de   False              True  rectangular
# 4            de   False             False  rectangular
# 5          None   False             False  rectangular
# 6          None   False              True  rectangular
# 7          None   False              True  rectangular
# 8            de   False              True  rectangular
# 9          None   False              True  rectangular
#
# [10 rows x 21 columns]

# %% [markdown]
# Wir erzeugen uns eigene Spalten, die sich besser interpretieren lassen.
# Den Code habe ich euch als Inspiration hier stehen lassen, damit ihr seht wie man an so etwas herangeht.
# Wir erzeugen für jede der Transformationen neue Spalten und lassen die alten erstmal wie sie sind.
#
# Wir können also anhand der vorhandenen Daten neue generieren, cool oder?

# %%
# Hier werden die Spalten 'created', 'published_at' und 'modified_at' in den Datentyp datetime konvertiert, um damit Datums- und Zeitoperationen durchzuführen.
youtube_data[['created','published_at','modified_at']] = youtube_data[['created','published_at','modified_at']].apply(pd.to_datetime)
# Dieser Code nimmt an, dass die Werte in der 'title'-Spalte Listen sind. Er extrahiert das letzte Element jeder Liste und speichert es in der 'title'-Spalte.
youtube_data['title'] = youtube_data['title'].apply(lambda x: x[-1])
# Hier wird die Differenz zwischen den 'modified_at' und 'created' Zeiten berechnet und das Ergebnis in Stunden angegeben. Dies zeigt, wie lange ein Video gebraucht hat, um in die Trends zu kommen.
youtube_data['trend_time_hours'] = (youtube_data['modified_at'] - youtube_data['created']) / pd.Timedelta(hours=1)
# Diese Zeile extrahiert den Wochentag (als Zahl von 0 bis 6, wobei 0 für Montag steht) aus dem 'created' Datum.
youtube_data['weekday'] = youtube_data['created'].dt.weekday
# Hier wird die Differenz zwischen den Zeiten 'created' und 'published_at' berechnet und das Ergebnis in Stunden angegeben.
youtube_data['hours_until_trend'] = (youtube_data['created'] - youtube_data['published_at']) / pd.Timedelta(hours=1)
# Diese Zeile berechnet das Wachstum der "Likes" eines Videos, indem sie die Differenz zwischen dem letzten und dem ersten Wert in der 'likes'-Liste berechnet.
youtube_data['likes_growth'] = youtube_data['likes'].apply(lambda x: x[-1] - x[0] if x[0] is not None and x[-1] is not None else None )
# Hier wird das Wachstum der "Likes" eines Videos pro Stunde berechnet, indem das gesamte "Likes"-Wachstum durch die Anzahl der Stunden, die das Video benötigt hat, um in die Trends zu kommen, geteilt wird.
youtube_data['likes_growth/hour'] = youtube_data['likes_growth'] / youtube_data['trend_time_hours']
# Diese Zeile extrahiert den ersten Rang eines Videos aus der 'rank'-Liste.
youtube_data['first_rank'] = youtube_data['rank'].apply(lambda x: x[0])
# Hier wird der beste (niedrigste) Rang eines Videos aus der 'rank'-Liste extrahiert.
youtube_data['best_rank'] = youtube_data['rank'].apply(lambda x: min(x))
# Diese Zeile berechnet das Wachstum der "Views" eines Videos, indem sie die Differenz zwischen dem letzten und dem ersten Wert in der 'likes'-Liste berechnet.
youtube_data['views_growth'] = youtube_data['views'].apply(lambda x: x[-1] - x[0] if x[0] is not None and x[-1] is not None else None )
# Hier wird das Wachstum der "Views" eines Videos pro Stunde berechnet, indem das gesamte "Views"-Wachstum durch die Anzahl der Stunden, die das Video benötigt hat, um in die Trends zu kommen, geteilt wird.
youtube_data['views_growth/hour'] = youtube_data['views_growth'] / youtube_data['trend_time_hours']

# Eine Spalte mit dem jeweils letzten Eintrag erzeugen (den aktuellesten)
youtube_data['views_cleaned'] = youtube_data['views'].apply(lambda x: x[-1])
youtube_data['likes_cleaned'] = youtube_data['likes'].apply(lambda x: x[-1])
youtube_data['dislikes_cleaned'] = youtube_data['dislikes'].apply(lambda x: x[-1])
youtube_data['comments_cleaned'] = youtube_data['comments'].apply(lambda x: x[-1])

# %% [markdown]
# Die Spalten enthalten jetzt folgende Infos:
#
# - Eindeutiges Identifikationsmerkmal (kurz ID),
# - Sprache des Videos,
# - Hat das Video Untertitel?,
# - Video Kategorie (Bildung, Unterhaltung...),
# - Kanalname,
# - ID des Kanals,
# - Datum der Erfassung durch das Skript,
# - Videobeschreibungs Text,
# - Länge des Videos,
# - Ist das Video lizenziert?,
# - Datum der letzten Bearbeitung,
# - Datum der Videoveröffentlichung,
# - Sprache der Untertitel,
# - Titel des Videos,
# - Wie viel Stunden ist das Video in den Trends, bevor es rausfliegt?,
# - Wochentag,
# - Wie viel Stunden braucht es, bevor es in die Trends kommt?,
# - Wachstum der Likes seit dem Trend,
# - Like-Wachstum pro Stunde,
# - Erster Trend-Ranking (1 bis 50),

# %%
youtube_data.head(10)
# Out:
#            _id                   created              published_at  \
# 0  QKWE-jtCI6A 2021-04-05 20:29:34+00:00 2021-04-04 11:14:13+00:00
# 1  omZDa8BRmjs 2021-04-05 20:29:34+00:00 2021-04-04 17:00:28+00:00
# 2  2XOFLRPnFC0 2021-04-05 20:29:34+00:00 2021-04-03 13:00:14+00:00
# 3  yyNBca9vYtw 2021-04-05 20:29:34+00:00 2021-04-04 18:00:19+00:00
# 4  6vrlsYoPT2U 2021-04-05 20:29:34+00:00 2021-04-04 11:23:07+00:00
# 5  epxBlEGItM4 2021-04-05 20:29:34+00:00 2021-04-03 22:17:12+00:00
# 6  va_dglw8qJI 2021-04-05 20:29:34+00:00 2021-04-04 10:01:05+00:00
# 7  61PVs2N61H0 2021-04-05 20:29:34+00:00 2021-04-04 21:57:24+00:00
# 8  5hdKcitAcqs 2021-04-05 20:29:34+00:00 2021-04-04 10:00:01+00:00
# 9  6r0_Vqmuwvo 2021-04-05 20:29:34+00:00 2021-04-03 18:58:05+00:00
#
#                 modified_at                          channel  \
# 0 2021-04-05 20:58:14+00:00                         Dagi Bee
# 1 2021-04-05 20:58:14+00:00                              Gnu
# 2 2021-04-06 22:37:06+00:00                      Brawl Stars
# 3 2021-04-05 20:58:14+00:00                        laserluca
# 4 2021-04-05 20:58:14+00:00                    Fynn Kliemann
# 5 2021-04-05 20:58:14+00:00  Deutschland sucht den Superstar
# 6 2021-04-05 20:58:14+00:00                       Bulien Jam
# 7 2021-04-09 01:15:06+00:00                      Technoblade
# 8 2021-04-05 20:58:14+00:00              Felix von der Laden
# 9 2021-04-05 20:58:14+00:00                  ELoTRiX - Clips
#
#                  channel_id  \
# 0  UCpZ_DI-ZugwMzXcqccaTVsg
# 1  UC0m40b5CPcB801gVEz25WuQ
# 2  UCooVYzDxdwTtGYAkcPmOgOw
# 3  UCmxc6kXbU1J-0pR2F3wIx9A
# 4  UCa_MF1hIC-oCTsEJDegmaIQ
# 5  UC6jGqtmHfNQiwKFxH__-rfA
# 6  UCNpP_PH0Uj8Ldc7INQ-ih_Q
# 7  UCFAiFyGs6oDiF1Nf-rRJpZA
# 8  UChr1sKJ27Fr6WZxAlusbo_w
# 9  UCMPROZGfCUp7vlVFS-nBF_A
#
#                                                 rank  \
# 0                                                [1]
# 1                                                [2]
# 2  [3, 15, 3, 16, 21, 22, 27, 28, 30, 33, 34, 31,...
# 3                                             [4, 5]
# 4                                             [5, 4]
# 5                                                [6]
# 6                                                [7]
# 7  [8, 1, 8, 1, 2, 3, 4, 5, 6, 7, 8, 9, 8, 9, 17,...
# 8                                                [9]
# 9                                               [10]
#
#                                                title  \
# 0  Ich habe mir 4 Tattoos gestochen ( Po & Hals 😳...
# 1  Üble GERÜCHTE über Anni und Gnu! Jetzt reichts...
# 2  Brawl Stars: Brawl Talk! Two New Brawlers, TON...
# 3                               ICH WERDE ÜBERFALLEN
# 4         Sowas wie n VLOG oderso #3 | Pic & Abfahrt
# 5  Jan-Marten Block mit "Never Not Try" | DSDS 20...
# 6  Meine ROOMTOUR 2021 vs 2017 - Viel hat sich ve...
# 7          I Must Win MrBeast's $10,000 Refrigerator
# 8                                     Es ist vorbei!
# 9  ROLEX von UNSYMPATHISCHTV GESCHENKT BEKOMMEN -...
#
#                                                 tags  category  ...  \
# 0  [[dagibee, dagi, daggi, daggy, beetique, dagi ...        26  ...
# 1  [[Saftiges Gnu, Saftigesgnu, gnumama, gnu, gnu...        24  ...
# 2  [[brawl stars, mobile game, mobile strategy ga...        20  ...
# 3                                             [None]        24  ...
# 4                                             [None]        24  ...
# 5  [[DSDS, RTLDSDS2012, Superstar, Deutschland su...        24  ...
# 6  [[Bulien Jam, Julien Bam, Roomtour, bulien Roo...        24  ...
# 7  [[Minecraft, Technoblade, Technothepig, Hypixel]]        20  ...
# 8  [[felixladen, dner, spielkind, vlog, 2020, Fel...        19  ...
# 9  [[elotrix, reactions, clips, elotrix clips, tw...        20  ...
#
#   likes_growth likes_growth/hour first_rank best_rank views_growth  \
# 0        145.0        303.488372          1         1         6757
# 1        209.0        437.441860          2         2         5014
# 2      18543.0        709.764811          3         3      3051500
# 3        282.0        590.232558          4         4         5282
# 4         62.0        129.767442          5         4         2160
# 5         70.0        146.511628          6         6         6073
# 6        249.0        521.162791          7         7         4019
# 7     165130.0       2151.281791          8         1      4036487
# 8         88.0        184.186047          9         9         2418
# 9         84.0        175.813953         10        10         1724
#
#    views_growth/hour views_cleaned likes_cleaned  dislikes_cleaned  \
# 0       14142.558140        382556       16675.0             777.0
# 1       10494.418605        302078       32633.0             519.0
# 2      116801.343937      20797544      940030.0           11778.0
# 3       11055.348837        427309       53118.0             590.0
# 4        4520.930233        174353       13596.0              81.0
# 5       12710.930233        749139       13556.0            1459.0
# 6        8411.860465        398872       38159.0             345.0
# 7       52586.574121       6988056      594257.0            3372.0
# 8        5060.930233        253470       19310.0             590.0
# 9        3608.372093        220157       16823.0             159.0
#
#    comments_cleaned
# 0             436.0
# 1            1564.0
# 2          114130.0
# 3            9963.0
# 4             283.0
# 5            1566.0
# 6            1543.0
# 7           30740.0
# 8             578.0
# 9             494.0
#
# [10 rows x 34 columns]

# %% [markdown]
# ### 3. Explorative Datenanalyse
# Zu Beginn einer Datenanalyse müssen wir die Daten mit statistischen Methoden auf Qualität untersuchen, dann können wir uns diverse Datenpunkte mit Plots anschauen.

# %% [markdown]
# ### 3.1 Übersicht über die Werte:
# - Wir wollen uns zunächst einen Überblick verschaffen, das geht mit der Funktion **info()**

# %%
youtube_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17951 entries, 0 to 17950
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   _id                17951 non-null  object
#  1   created            17951 non-null  datetime64[ns, UTC]
#  2   published_at       17951 non-null  datetime64[ns, UTC]
#  3   modified_at        17951 non-null  datetime64[ns, UTC]
#  4   channel            17951 non-null  object
#  5   channel_id         17951 non-null  object
#  6   rank               17951 non-null  object
#  7   title              17951 non-null  object
#  8   tags               17951 non-null  object
#  9   category           17951 non-null  int64
#  10  description        17951 non-null  object
#  11  likes              17951 non-null  object
#  12  dislikes           17951 non-null  object
#  13  comments           17951 non-null  object
#  14  views              17951 non-null  object
#  15  duration           17951 non-null  int64
#  16  audio_language     12463 non-null  object
#  17  text_language      4743 non-null   object
#  18  caption            17951 non-null  bool
#  19  licensed_content   17951 non-null  bool
#  20  projection         17951 non-null  object
#  21  trend_time_hours   17951 non-null  float64
#  22  weekday            17951 non-null  int32
#  23  hours_until_trend  17951 non-null  float64
#  24  likes_growth       17900 non-null  float64
#  25  likes_growth/hour  17900 non-null  float64
#  26  first_rank         17951 non-null  int64
#  27  best_rank          17951 non-null  int64
#  28  views_growth       17951 non-null  int64
#  29  views_growth/hour  17951 non-null  float64
#  30  views_cleaned      17951 non-null  int64
#  31  likes_cleaned      17900 non-null  float64
#  32  dislikes_cleaned   9056 non-null   float64
#  33  comments_cleaned   17700 non-null  float64
# dtypes: bool(2), datetime64[ns, UTC](3), float64(8), int32(1), int64(6), object(14)
# memory usage: 4.3+ MB

# %% [markdown]
# ### 3.2 Fehlende Werte:
# - die Funktion **isnull()** sagt euch wie ob Werte null (boolean) sind und **sum()** summiert sie pro Spalte auf.

# %%
# Überprüfen auf fehlende Werte
missing_values = youtube_data.isnull().sum()
missing_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #
# 12656  [1, 2, 3, 4, 5, 4, 5, 6, 5, 6, 7, 5, 6, 10, 12...
# 12793  [18, 17, 15, 16, 15, 16, 14, 13, 12, 17, 33, 3...
# 12827  [9, 6, 5, 6, 24, 17, 18, 19, 16, 17, 19, 20, 1...
# 13304  [37, 40, 37, 40, 39, 37, 39, 37, 38, 37, 38, 3...
# 13476  [14, 15, 14, 19, 20, 19, 20, 21, 22, 21, 22, 2...
# 13929  [32, 31, 30, 29, 30, 29, 32, 34, 33, 38, 37, 4...
# 14248  [13, 14, 15, 16, 17, 16, 17, 16, 17, 16, 15, 1...
# 14747                                   [37, 38, 37, 36]
# 15054                                       [28, 29, 28]
# 15921  [4, 3, 2, 1, 2, 5, 6, 7, 8, 7, 15, 16, 20, 21,...
# 16014                           [37, 48, 49, 50, 48, 47]
# 16763   [25, 24, 25, 24, 28, 45, 48, 49, 50, 49, 48, 49]
# 17234                                             [2, 1]
# 17525  [8, 9, 11, 12, 13, 17, 18, 19, 18, 19, 20, 21,...
# 17773  [7, 8, 9, 12, 14, 16, 17, 19, 22, 21, 24, 25, ...
#
#                                                    title  \
# 503              Marc Anthony - Una Noche (Full Concert)
# 735    Galaxy Unpacked April 2021: Official Replay | ...
# 1250           FINAL FANTASY XIV: ENDWALKER Full Trailer
# 1251          FINAL FANTASY XIV: ENDWALKER Reaper Reveal
# 1868             I can’t believe this happened 😂 #shorts
# 1941   Eliminatorias Sudamericanas | Perú vs Colombia...
# 1963   Eliminatorias Sudamericanas | Brasil vs Ecuado...
# 2022   How to Serve Drinks in the June's Journey Dete...
# 2218   OMG What's happening? #shorts​ Cool videos fro...
# 3174      INSIDE KYLIE COSMETICS PART ONE: THE BEGINNING
# 3252   INSIDE KYLIE COSMETICS PART TWO: DISRUPTING TH...
# 3293           DRAGON BALL LEGENDS "Video and Stuff #15"
# 3379        INSIDE KYLIE COSMETICS PART THREE: KYLIE 2.0
# 4220   Join the BTS #PermissiontoDance Challenge only...
# 4313                     THE BOYZ(더보이즈) ‘THRILL RIDE’ MV
# 4347   Galaxy Unpacked August 2021: Official Replay |...
# 4550                Make your Keyboard Better With This!
# 5386   Eliminatorias Sudamericanas | Argentina 3-0 Bo...
# 5576           DRAGON BALL LEGENDS "Video and Stuff #17"
# 5712          FINAL FANTASY XIV: ENDWALKER - Job Actions
# 5935                              Introducing Kylie Baby
# 6533   Eliminatorias Sudamericanas | Perú 2-0 Chile |...
# 6812       Eliminatorias | Brasil 4-1 Uruguay | Fecha 12
# 8074   Mein Mann bittet 3 Mal pro Woche, dieses Kuche...
# 8280                                                   ❤
# 8469                                  Grüße zum Advent 🎄
# 8479                                  Zum Adventssonntag
# 8925   You need to be friends with her 😂 #shorts Cool...
# 9714   🍾 Happy New Year Frohes gesundes glückliches N...
# 10619  Einfach und schnell! Meine Familie bittet mich...
# 10706     Eliminatorias | Chile 1-2 Argentina | Fecha 15
# 11033  Kamila Valieva Makes History To Send Russian O...
# 11196  Galaxy Unpacked February 2022: Official Replay...
# 11325  Werfen Sie Walnüsse in kochendes Wasser!  Die ...
# 11563  Nur wenige Leute kochen Kuchen so! Sie werden ...
# 12416         DRAGON BALL LEGENDS  "REVEALS ＆ STUFF #21"
# 12656                                         To Our Son
# 12793        Eliminatorias | Brasil 4-0 Chile | Fecha 17
# 12827  Eliminatorias | Argentina 3-0  Venezuela | Fec...
# 13304  Red Hot Chili Peppers “Under the Bridge” Live ...
# 13476                                   Mein Statement .
# 13929  Warum kannte ich dieses Rezept vorher nicht? g...
# 14248  Married to the Met | Get Ready for the Met Gal...
# 14747                    GOT7 EP 《GOT7》 HIGHLIGHT MEDLEY
# 15054         Willow | Official Teaser Trailer | Disney+
# 15921                               DIE MÄDCHEN WG 2016.
# 16014  DRAGON BALL LEGENDS REVEALS ＆ STUFF SPECIAL ED...
# 16763  DRAGON BALL LEGENDS REVEALS ＆ STUFF SPECIAL ED...
# 17234                               Celebrating Steelpan
# 17525                      Pokémon Presents | 03.08.2022
# 17773  Samsung Galaxy Unpacked August 2022: Official ...
#
#                                                     tags  category  ...  \
# 503    [[marc anthony new album, marc anthony new son...        10  ...
# 735    [[Samsungevent, Galaxy Unpacked, Unpacked, Sam...        28  ...
# 1250   [[FF14, FFXIV, Final Fantasy XIV (Video Game),...        20  ...
# 1251   [[FF14, FFXIV, Final Fantasy XIV (Video Game),...        20  ...
# 1868                                              [None]        10  ...
# 1941   [[fútbol, pelota, gol, copa, libertadores, sud...        17  ...
# 1963   [[fútbol, pelota, gol, copa, libertadores, sud...        17  ...
# 2022                                              [None]        20  ...
# 2218   [[YELLOWIKI, yelowiki, shorts, short, tiktok, ...        22  ...
# 3174   [[Kylie Jenner, Kylie Cosmetics, Kris Jenner, ...        22  ...
# 3252                                              [None]        22  ...
# 3293   [[876TV, 876, バンダイナムコ, バンダイナムコエンターテインメント, バンナム...        20  ...
# 3379                                              [None]        22  ...
# 4220                                              [None]        27  ...
# 4313   [[크래커엔터테인먼트, Cre.ker Entertainment, 크래커, Creke...        10  ...
# 4347   [[Samsungevent, SamsungEvent, Galaxy Unpacked,...        28  ...
# 4550   [[how make keyboard better, how to make your k...        20  ...
# 5386   [[fútbol, pelota, gol, copa, libertadores, sud...        17  ...
# 5576   [[バンダイナムコ, バンナム, 876, 876TV, BNE, バンダイナムコエンターテ...        20  ...
# 5712   [[FF14, FFXIV, Final Fantasy XIV (Video Game),...        20  ...
# 5935                                              [None]        22  ...
# 6533   [[fútbol, pelota, gol, copa, libertadores, sud...        17  ...
# 6812   [[fútbol, pelota, gol, copa, libertadores, sud...        17  ...
# 8074   [[Leckere Minute, rezept, rezepte, ann kocht, ...        22  ...
# 8280   [[die, sims, deutsch, german, letsplayerin, 10...        20  ...
# 8469   [[Grußvideo, Zum Versenden per WhatsApp, Gute ...        24  ...
# 8479   [[Liebe Grüße, Grußvideo für, Zum Versenden pe...        24  ...
# 8925   [[YELLOWIKI, yelowiki, shorts, short, Funny Ch...        22  ...
# 9714   [[silvester, neujahr, neues, jahr, gesundheit,...         1  ...
# 10619  [[leckere Küche, Einfach und schnell, Meine Fa...        22  ...
# 10706  [[fútbol, pelota, gol, copa, libertadores, sud...        17  ...
# 11033  [[eurosport, live sport, sports, olympic games...        17  ...
# 11196  [[Samsungevent, SamsungEvent, Galaxy Unpacked,...        28  ...
# 11325  [[Meine leckere Küche, rezept, rezepte, einfac...        22  ...
# 11563  [[Leckere Minute, rezepte, kuchenrezept, einfa...        22  ...
# 12416  [[バンダイナムコ, バンナム, 876, 876TV, BNE, バンダイナムコエンターテ...        20  ...
# 12656                     [[Kylie Jenner, Travis Scott]]        22  ...
# 12793  [[fútbol, pelota, gol, copa, libertadores, sud...        17  ...
#
# 12656           28837.0
# 12793            6410.0
# 12827            5250.0
# 13304            1077.0
# 13476               NaN
# 13929             104.0
# 14248            4567.0
# 14747           13809.0
# 15054            2032.0
# 15921            2242.0
# 16014               NaN
# 16763               NaN
# 17234               NaN
# 17525             287.0
# 17773               NaN
#
# [51 rows x 34 columns]

# %% [markdown]
# ### 3.2 Sprache
# Sind denn alle Videos auch deutsch?

# %%
language = youtube_data['text_language'].dropna().groupby(youtube_data['text_language'].fillna('').apply(lambda x: x[0:2])).size().sort_values(ascending=False)
language
# Out:
# text_language
# en    2548
# de    1971
# ko     116
# es      44
# tr      15
# ro      12
# ja      10
# ar       6
# sq       4
# sr       3
# zh       2
# fr       2
# it       2
# ru       2
# vi       1
# aa       1
# pt       1
# pl       1
# bs       1
# nl       1
# Name: text_language, dtype: int64

# %%
mailab = youtube_data[youtube_data['_id'] == 'KEggd1S9_9Y'].iloc[0]
mailab['audio_language']
# Out:
# 'en'

# %% [markdown]
# Was ist das problem mit diesen Daten? Es gibt Inhalt der mit englischem Audio gelistet ist aber eigentlich ein deutscher kanal ist.
#
# Solche Fehler sind eigentlich schlecht für die Analyse und machen die Daten u.U. unbrauchbar.
# Aber wir wollen uns die Daten trotzdem mal ansehen und schauen welche Erkenntnisse wir im Allgemeinen gewinnen können.

# %%
#Wir löschen einige der Spalten auf denen wir nicht arbeiten werden:
youtube_data = youtube_data.drop(['_id','created','modified_at','channel_id','rank','tags','description','likes','dislikes','comments','views', 'text_language','audio_language'], axis=1)

# %%
# und auch die Einträge die null Werte enthalten benötigen wir nicht:
youtube_data = youtube_data.dropna()
youtube_data
# Out:
#                   published_at            channel  \
# 0    2021-04-04 11:14:13+00:00           Dagi Bee
# 1    2021-04-04 17:00:28+00:00                Gnu
# 2    2021-04-03 13:00:14+00:00        Brawl Stars
# 3    2021-04-04 18:00:19+00:00          laserluca
# 4    2021-04-04 11:23:07+00:00      Fynn Kliemann
# ...                        ...                ...
# 9096 2021-12-11 15:00:23+00:00            RedSama
# 9097 2021-12-11 18:43:30+00:00  Sky Sport Austria
# 9099 2021-12-12 08:00:10+00:00   Subi Performance
# 9116 2021-12-12 09:11:26+00:00      Tim Budesheim
# 9118 2021-12-12 04:00:08+00:00     Genshin Impact
#
#                                                   title  category  duration  \
# 0     Ich habe mir 4 Tattoos gestochen ( Po & Hals 😳...        26      1062
# 1     Üble GERÜCHTE über Anni und Gnu! Jetzt reichts...        24       889
# 2     Brawl Stars: Brawl Talk! Two New Brawlers, TON...        20       255
# 3                                  ICH WERDE ÜBERFALLEN        24       879
# 4            Sowas wie n VLOG oderso #3 | Pic & Abfahrt        24       348
# ...                                                 ...       ...       ...
# 9096  DOUBLE PUMP IST ZURÜCK und es ist BESSER ALS N...        20       554
# 9097  Adeyemi mit Hattrick! | RB Salzburg - WSG Tiro...        17       440
# 9099  WOW ! Diese Technik rettet Motoren binnen Seku...         2      2095
# 9116                               Etwas privates... ⛔️        17       279
# 9118  Character Demo - "Arataki Itto: Make Way for t...        20       155
#
#       caption  licensed_content   projection  trend_time_hours  weekday  ...  \
# 0       False              True  rectangular          0.477778        0  ...
# 1       False              True  rectangular          0.477778        0  ...
# 2        True              True  rectangular         26.125556        0  ...
# 3       False              True  rectangular          0.477778        0  ...
# 4       False             False  rectangular          0.477778        0  ...
# ...       ...               ...          ...               ...      ...  ...
# 9096    False              True  rectangular         15.416389        0  ...
# 9097    False              True  rectangular         12.233056        0  ...
# 9099    False              True  rectangular         15.416389        0  ...
# 9116    False             False  rectangular          8.083333        0  ...
# 9118     True             False  rectangular          5.683333        0  ...
#
#       likes_growth  likes_growth/hour  first_rank  best_rank  views_growth  \
# 0            145.0         303.488372           1          1          6757
# 1            209.0         437.441860           2          2          5014
# 2          18543.0         709.764811           3          3       3051500
# 3            282.0         590.232558           4          4          5282
# 4             62.0         129.767442           5          4          2160
# ...            ...                ...         ...        ...           ...
# 9096         412.0          26.724806          32         22          8132
# 9097          68.0           5.558709          33         30          7128
# 9099         376.0          24.389629          36         30         17156
# 9116         201.0          24.865979          40         40          3645
# 9118        3493.0         614.604106          45         45         80293
#
#       views_growth/hour  views_cleaned  likes_cleaned  dislikes_cleaned  \
# 0          14142.558140         382556        16675.0             777.0
# 1          10494.418605         302078        32633.0             519.0
# 2         116801.343937       20797544       940030.0           11778.0
# 3          11055.348837         427309        53118.0             590.0
# 4           4520.930233         174353        13596.0              81.0
# ...                 ...            ...            ...               ...
# 9096         527.490585          91339         7543.0             124.0
# 9097         582.683531         124861         2596.0              33.0
# 9099        1112.841673          97502         4079.0              51.0
# 9116         450.927835          47080         4951.0              45.0
# 9118       14127.800587        1942176       223262.0             872.0
#
#       comments_cleaned
# 0                436.0
# 1               1564.0
# 2             114130.0
# 3               9963.0
# 4                283.0
# ...                ...
# 9096             277.0
# 9097              96.0
# 9099             355.0
# 9116             480.0
# 9118           11590.0
#
# [8954 rows x 21 columns]

# %% [markdown]
# ### 3.3 **Beliebteste Kategorien: Welche Kategorien von Videos sind am häufigsten in den Trends?**
#
# Wir sehen nun, dass die Videokategorien nur als IDs Daten vorliegen. Das ist natürlich doof für uns.
# Wir werden die Kategorien mappen, sodass die IDs durch die tatsächlichen Namen der Kategorien ersetzt werden.
# Dies wird es uns erleichtern, die Daten zu analysieren und die Ergebnisse zu interpretieren.
# Anschließend werden wir untersuchen, welche Kategorien von Videos am häufigsten in den Trends sind.

# %%
# Kategorien-Dictionary erstellen
category_mapping = {
    1: "Film & Animation",
    2: "Autos & Vehicles",
    10: "Music",
    15: "Pets & Animals",
    17: "Sports",
    18: "Short Movies",
    19: "Travel & Events",
    20: "Gaming",
    21: "Videoblogging",
    22: "People & Blogs",
    23: "Comedy",
    24: "Entertainment",
    25: "News & Politics",
    26: "Howto & Style",
    27: "Education",
    28: "Science & Technology",
    29: "Nonprofits & Activism",
    30: "Movies",
    31: "Anime/Animation",
    32: "Action/Adventure",
    33: "Classics",
    34: "Comedy",
    35: "Documentary",
    36: "Drama",
    37: "Family",
    38: "Foreign",
    39: "Horror",
    40: "Sci-Fi/Fantasy",
    41: "Thriller",
    42: "Shorts",
    43: "Shows",
    44: "Trailers"
}

# Kategorien mappen
# Wir erstellen eine neue Spalte mit den Kategorienamen
youtube_data['category_name'] = youtube_data['category'].map(category_mapping)

# %%
# jetzt können wir auch category löschen:
youtube_data = youtube_data.drop(['category'],axis=1)
youtube_data.head()
# Out:
#                published_at        channel  \
# 0 2021-04-04 11:14:13+00:00       Dagi Bee
# 1 2021-04-04 17:00:28+00:00            Gnu
# 2 2021-04-03 13:00:14+00:00    Brawl Stars
# 3 2021-04-04 18:00:19+00:00      laserluca
# 4 2021-04-04 11:23:07+00:00  Fynn Kliemann
#
#                                                title  duration  caption  \
# 0  Ich habe mir 4 Tattoos gestochen ( Po & Hals 😳...      1062    False
# 1  Üble GERÜCHTE über Anni und Gnu! Jetzt reichts...       889    False
# 2  Brawl Stars: Brawl Talk! Two New Brawlers, TON...       255     True
# 3                               ICH WERDE ÜBERFALLEN       879    False
# 4         Sowas wie n VLOG oderso #3 | Pic & Abfahrt       348    False
#
#    licensed_content   projection  trend_time_hours  weekday  \
# 0              True  rectangular          0.477778        0
# 1              True  rectangular          0.477778        0
# 2              True  rectangular         26.125556        0
# 3              True  rectangular          0.477778        0
# 4             False  rectangular          0.477778        0
#
#    hours_until_trend  ...  likes_growth/hour  first_rank  best_rank  \
# 0          33.255833  ...         303.488372           1          1
# 1          27.485000  ...         437.441860           2          2
# 2          55.488889  ...         709.764811           3          3
# 3          26.487500  ...         590.232558           4          4
# 4          33.107500  ...         129.767442           5          4
#
#    views_growth  views_growth/hour  views_cleaned  likes_cleaned  \
# 0          6757       14142.558140         382556        16675.0
# 1          5014       10494.418605         302078        32633.0
# 2       3051500      116801.343937       20797544       940030.0
# 3          5282       11055.348837         427309        53118.0
# 4          2160        4520.930233         174353        13596.0
#
#    dislikes_cleaned  comments_cleaned  category_name
# 0             777.0             436.0  Howto & Style
# 1             519.0            1564.0  Entertainment
# 2           11778.0          114130.0         Gaming
# 3             590.0            9963.0  Entertainment
# 4              81.0             283.0  Entertainment
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Aufgabenteil:
# #### Wie viele Videos gibt es pro Kategorie?
# - Wie man sieht hat Pandas die neue Spalte ans Ende des DataFrames angehängt.
# - Als nächstes wollen wir die **Anzahl der Videos pro Kategorie** zählen, um unsere Fragesetellung zu beantworten.
# <span style="color:red">
# **Jetzt seid ihr dran! Schreibt den Python Code dafür in die nächste Zelle.**
# - Hinweis: ich habe das gewünschte Ergebnis bereits in der Zeile darunter geplottet. Eures soll genauso aussehen!
# </span>

# %%
videoCountPerCat = youtube_data['category_name'].value_counts()
videoCountPerCat
# Out:
# category_name
# Entertainment            4182
# Gaming                   3107
# Music                    2653
# Sports                   2047
# People & Blogs           1956
# Comedy                    744
# News & Politics           606
# Autos & Vehicles          538
# Science & Technology      530
# Howto & Style             492
# Education                 487
# Film & Animation          442
# Travel & Events            93
# Pets & Animals             59
# Nonprofits & Activism      15
# Name: count, dtype: int64

# %%
### hier nichts ausführen, sonst verschwindet der Output.

# %% [markdown]
# Cool, wie es aussieht ist Wissenschaft und Technik sogar in den Top 10!

# %% [markdown]
# #### **Erstelle daraus ein Balkendiagramm um es zu visualisieren.**
# - Färbe alle Balken zunächst grau ein
# - Färbe den Balken für 'Gaming' grün ein
# - Hinweis: Wir benötigen dafür die Bibliothek ``matplotlib`` (siehe Bibliotheken)
#
# <span style="color:red">
# **Schreibt den Python Code dafür in die nächste Zelle.**
# </span>

# %%
#videoCountPerCat.plot.bar()
sns.set(style="darkgrid")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = videoCountPerCat.index
students = videoCountPerCat.array
bar_colors = 'tab:grey'
barlist=ax.bar(langs,students,color=bar_colors)

index = videoCountPerCat.index.get_loc('Gaming')

barlist[index].set_color('green') # das muss eleganter gehen
plt.xticks(rotation=90)
plt.show()

# %%
### hier nichts ausführen, sonst verschwindet der Output.

# %% [markdown]
# Nun widmen wir uns der zweiten Fragestellung:
#
#
# ### Analyse der Frage "Was macht ein gutes Gaming-Video aus?":
#
# Wir benötigen also nur die Daten über Gaming, richtig?
#
# - Extrahiere die Daten anhand der **Kategorie** Gaming, um darauf arbeiten zu können.
# - Hinweis: Pandas mag es nicht, wenn man direkt auf einem Slice arbeitet, erstellt daher eine Kopie von dem Slice (copy()), damit keine Fehler entstehen.
# <span style="color:red">
# **Schreibt den Python Code dafür in die nächste Zelle. **
# </span>

# %%
gaming_data = youtube_data[youtube_data['category_name']=='Gaming'].copy()
gaming_data
# Out:
#                _id                   created              published_at  \
# 2      2XOFLRPnFC0 2021-04-05 20:29:34+00:00 2021-04-03 13:00:14+00:00
# 7      61PVs2N61H0 2021-04-05 20:29:34+00:00 2021-04-04 21:57:24+00:00
# 9      6r0_Vqmuwvo 2021-04-05 20:29:34+00:00 2021-04-03 18:58:05+00:00
# 19     5ZAZEaFlV14 2021-04-05 20:29:34+00:00 2021-04-04 19:00:00+00:00
# 24     Xqamnbm-ZLA 2021-04-05 20:29:34+00:00 2021-04-04 18:14:54+00:00
# ...            ...                       ...                       ...
# 17914  yoemm2g5ItQ 2022-08-13 23:32:04+00:00 2022-08-13 09:04:50+00:00
# 17919  MwYZY2Tr7wI 2022-08-14 17:13:03+00:00 2022-08-14 08:00:15+00:00
# 17929  Y2kSWgsO6Hs 2022-08-14 17:13:04+00:00 2022-08-14 07:27:25+00:00
# 17933  g6ejKmCpfLY 2022-08-14 17:52:03+00:00 2022-08-13 13:39:05+00:00
# 17940  WIxkKExpu94 2022-08-14 17:52:04+00:00 2022-08-13 13:00:16+00:00
#
#                     modified_at          channel                channel_id  \
# 2     2021-04-06 22:37:06+00:00      Brawl Stars  UCooVYzDxdwTtGYAkcPmOgOw
# 7     2021-04-09 01:15:06+00:00      Technoblade  UCFAiFyGs6oDiF1Nf-rRJpZA
# 9     2021-04-05 20:58:14+00:00  ELoTRiX - Clips  UCMPROZGfCUp7vlVFS-nBF_A
# 19    2021-04-07 22:56:06+00:00            Grian  UCR9Gcq0CMm6YgTzsDxAxjOQ
# 24    2021-04-08 18:09:06+00:00   MrBeast Gaming  UCIPPMRA040LQr5QPyJEbmXA
# ...                         ...              ...                       ...
# 17914 2022-08-14 17:12:05+00:00   Standart Skill  UCQ_hHJ0uTbzFLHrk1XHGXtw
# 17919 2022-08-15 09:53:04+00:00    SpontanaBlack  UCppK6hGo5L-dmrryG5T0K0Q
# 17929 2022-08-15 09:53:05+00:00            Wakez  UCNa_VPw5pb_u4b6tTRdFJvg
# 17933 2022-08-15 09:53:04+00:00       LarsOderSo  UCY2Fi1VCADHR7Ln5tRVCXxg
# 17940 2022-08-15 09:53:05+00:00   Genshin Impact  UCiS882YPwZt1NfaM0gR0D9Q
#
#                                                     rank  \
# 2      [3, 15, 3, 16, 21, 22, 27, 28, 30, 33, 34, 31,...
# 7      [8, 1, 8, 1, 2, 3, 4, 5, 6, 7, 8, 9, 8, 9, 17,...
# 9                                                   [10]
# 19     [20, 3, 20, 3, 4, 5, 6, 7, 13, 14, 15, 23, 24,...
# 24     [25, 8, 26, 7, 6, 7, 8, 9, 8, 9, 10, 11, 18, 2...
# ...                                                  ...
# 17914       [49, 48, 47, 46, 45, 44, 42, 41, 40, 41, 42]
# 17919         [6, 3, 6, 5, 6, 5, 6, 7, 6, 7, 6, 7, 6, 7]
# 17929                   [46, 39, 49, 50, 45, 48, 49, 48]
# 17933  [14, 13, 12, 13, 11, 12, 16, 18, 17, 20, 19, 2...
# 17940  [36, 37, 36, 37, 36, 38, 47, 48, 47, 50, 49, 5...
#
#                                                    title  \
# 2      Brawl Stars: Brawl Talk! Two New Brawlers, TON...
# 7              I Must Win MrBeast's $10,000 Refrigerator
# 9      ROLEX von UNSYMPATHISCHTV GESCHENKT BEKOMMEN -...
# 19        Hermitcraft 7: Episode 73 - C.E.O of BARGE Co.
# 24                       Hide And Seek Across The Earth!
# ...                                                  ...
# 17914       ich FAHRE ein RENNEN mit dem 10.000 PS AUTO!
# 17919  So WEIT ist er NOCH NIE gekommen!!!😱 | Alt F4 ...
# 17929  FIFA 22: NEYMAR FUTTIES Squad Builder Battle 🔥...
# 17933  Ich zeige meine Katzen.. mögen meine Katzen de...
# 17940  Version 3.0 "The Morn a Thousand Roses Brings"...
#
#                                                     tags  category  ...  \
# 2      [[brawl stars, mobile game, mobile strategy ga...        20  ...
# 7      [[Minecraft, Technoblade, Technothepig, Hypixel]]        20  ...
# 9      [[elotrix, reactions, clips, elotrix clips, tw...        20  ...
# 19     [[Minecraft, Grian, building, grian, mincraft,...        20  ...
# 24                                                [None]        20  ...
# ...                                                  ...       ...  ...
# 17914  [[GTA 5, GTA 5 neu, GTA 5 HAi, GTA 6 Angeln, G...        20  ...
# 17919  [[montanablack twitch, montanablack best of, m...        20  ...
# 17929  [[Fifa 22, Wakez, Proownez, Sbb, Squad Builder...        20  ...
# 17933                                             [None]        20  ...
# 17940  [[Amber, amber vtuber, genshi, genshi game, ge...        20  ...
#
#       likes_growth/hour first_rank best_rank views_growth views_growth/hour  \
# 2            709.764811          3         3      3051500     116801.343937
# 7           2151.281791          8         1      4036487      52586.574121
# 9            175.813953         10        10         1724       3608.372093
# 19           371.930482         20         3       678741      13455.810829
# 24          2161.360917         25         6      6372900      91487.247380
# ...                 ...        ...       ...          ...               ...
# 17914         72.338485         49        40        42258       2391.924655
# 17919        286.615223          6         3       126581       7594.733421
# 17929        142.977617         46        39        37287       2237.182714
# 17933         54.504778         14        11        27853       1738.970882
# 17940        722.360001         36        36       280912      17538.426319
#
#        views_cleaned likes_cleaned dislikes_cleaned  comments_cleaned  \
# 2           20797544      940030.0          11778.0          114130.0
# 7            6988056      594257.0           3372.0           30740.0
# 9             220157       16823.0            159.0             494.0
# 19           1983417      119843.0            807.0           21864.0
# 24          14851126      697718.0           9338.0           50360.0
# ...              ...           ...              ...               ...
# 17914         153779       10004.0              NaN             320.0
# 17919         275236       17696.0              NaN             239.0
# 17929          81433        8077.0              NaN             105.0
# 17933         159457        9911.0              NaN             716.0
# 17940        2473099      228714.0              NaN           11864.0
#
#        category_name
# 2             Gaming
# 7             Gaming
# 9             Gaming
# 19            Gaming
# 24            Gaming
# ...              ...
# 17914         Gaming
# 17919         Gaming
# 17929         Gaming
# 17933         Gaming
# 17940         Gaming
#
# [3107 rows x 35 columns]

# %%
### hier nichts ausführen, sonst verschwindet der Output.

# %% [markdown]
# Jetzt können wir diverse Plots erstellen und uns ansehen, was die beliebtesten Gamingvideos ausmachen.
# Anschließend können wir daran Aussagen treffen.

# %% [markdown]
# Um herauszufinden, was das "beliebteste" Gaming-Video ausmacht, müssen wir zunächst definieren, was "beliebt" bedeutet.
# Ist es die Anzahl der Ansichten, die Anzahl der Likes, Kommentare oder eine Kombination davon?

# %% [markdown]
# ### Kriterien:
# Lasst uns die Daten basierend auf den folgenden Kriterien analysieren:
#
# 1. **Popularität**:
#     - Verteilung der Anzahl der Aufrufe und Likes.
#     - Top-Videos basierend auf Ansichten und Likes.
#
# 2. **Performance von Kanälen**:
#     - welche Kanäle haben im Durchschnitt die meisten Aufrufe und Likes
#
# 3. **Verteilung der Videolänge**
#    - Verteilung der Videolängen für die beliebtesten Videos
#
# 4. **Schnelligkeit des Trends**:
#     - Verteilung der Stunden bis zum Trend ("hours_until_trend").
#     - Top-Videos, die am schnellsten in die Trends gekommen sind.
#
# 4. **Wochentag der Veröffentlichung**:
#     - Analyse des Veröffentlichungstags der Woche.
#
# -----
#
# Beginnen wir mit dem ersten Punkt:
# ### 1. Popularität.
# - Wir plotten die Verteilung der Views und der Likes
# - nutzt dafür ein Histogramm
# - nutzt die Bibliothek ``seaborn``
#
#
# <span style="color:red">
# **Schreibt den Python Code dafür in die nächste Zelle. **
# </span>

# %%
### Hier sollte euer Code stehen

f, axes = plt.subplots(2,1,figsize=(13, 26)) # mit figsize passt man die größe an. (surprise)
h=sns.histplot(gaming_data.views_cleaned,kde=True,ax=axes[0])
h.set(xlabel="Anzahl Views (cleaned)",ylabel="Häufigkeit",title="Geiler Scheiß!")
axes[0].ticklabel_format(axis='x',style='plain')
axes[1].ticklabel_format(axis='x',style='plain')
sns.histplot(gaming_data.likes_cleaned,kde=True,ax=axes[1]).set(xlabel="Anzahl Likes (cleaned)",ylabel="Häufigkeit",title="Geiler Scheiß, DER FILM!")

# Frage: wie definiert man die Größe der Plots? 

plt.show()

# %%
### hier nichts ausführen, sonst verschwindet der Output.

# %% [markdown]
# ### Analyse:
# <span style="color:red">
# **Schreibt den eine kurze Analyse und Interpretation der Plots. **
# </span>

# %% [markdown]
# ### Analyse:
#
# - Es gibt viele Videos, welche selten gesehen und selten gelike Werden.
# - Die verteilung von Views und Likes ist korreliert, vermutlich besteht eine Kausalität.

# %% [markdown]
# ### 2. Performance verschiedener Kanäle
# Als nächstes werden wir die Performance verschiedener Kanäle analysieren und herausfinden, welche Kanäle im Durchschnitt die meisten Aufrufe und Likes haben.
#
# - nutzt dafür auch die Bibliothek seaborn
# - Tipp: nutzt die Funktionen **groupby()** und **agg()** um Daten zu filtern
# - wir berechnen den Durchschnitt
# - danach plotten wir die Views mit einem Balkendiagramm (barplot)
# - und die Likes mit einem Liniendiagramm (lineplot)
# <span style="color:red">
# **Schreibt den Python Code dafür in die nächste Zelle. **
# </span>

# %%
### hier sollte euer Code stehen
# nimm die gaming daten,                                       gaming_data...
# gruppiere nach channel,                                      ...groupby('channel')...
# berechne die mittelwerte (der Numerischen eigenschaften???)  ...mean()...
# sortiere das ergebnis, absteigend nach views_cleaned         ...sort_values(by="views_cleaned", ascending=False)...
# nimm die ersten 10 Zeilen/ergebnisse                         ...[0:10]
relevante_channels = gaming_data.groupby('channel').mean(numeric_only=True).sort_values(by="views_cleaned", ascending=False)[0:10] #gaming_data['views_cleaned'].sort_values(ascending=False)[0:10]


fig, ax1 = plt.subplots(figsize=(18,9)) # keine ahnung.

ax2 = ax1.twinx() # die x-achse duplizieren, um die beiden plots zu überlagern. 

# den bar-plot anlegen.
sns.barplot(x=relevante_channels.index,
            y='views_cleaned',
            data=relevante_channels,
            palette = "Blues", # diese zeile mach die bunten balken. 
            ax=ax1) 

# die rote linie malen
sns.lineplot(data = relevante_channels["likes_cleaned"],color='red',linewidth=2, marker='o', sort = False, ax=ax2) 

plt.xticks(rotation=70) # FG: EIgentlich sollten die label gedreht sein.... schade

ax1.ticklabel_format(axis='y',style='plain') # die AchenBeschriftung in 'normalerweise' langer darstellung ausschreiben
ax2.ticklabel_format(axis='y',style='plain') # die AchenBeschriftung in 'normalerweise' langer darstellung ausschreiben

#plt.show()

#relevante_channels.dtypes
#relevante_channels.index

# %%
### hier nichts ausführen, sonst verschwindet der Output.

# %% [markdown]
# ### Analyse
# <span style="color:red">
# **Schreibt den eine kurze Analyse und Interpretation der Plots. **
# </span>

# %% [markdown]
# ### Analyse:
#
# - Bei dem Graphen, wie er von uns erzeugt wurde, besteht scheinbar keine Korrelation zwischen Views und likes.
# - Channel können extreme Diskrepanzen aufweisen, oder aber bei  mittelmäßig viel Views auch mittelmäßig viel Likes haben
# - Dies ist überraschend
#
# Das Diagram, wie in der Vorlage, erscheint intuitiver: Hier scheinen Views und Likes korreliert zu sein.

# %% [markdown]
# ### 3. Videodauer
#
# Wir werden die Daten in Bezug auf die Video-Dauer weiter analysieren und sie in einem Histogramm darstellen, um die Verteilung der Videolängen für die beliebtesten Videos (basierend auf Aufrufen und Likes) zu zeigen.
#
# Geht bitte wie folgt vor:
#
# - Videos in verschiedene Kategorien einteilen basierend auf ihrer Dauer (z.B. 0-5 Minuten, 5-10 Minuten, usw.).
# - Durchschnitt der Aufrufe und Likes für jede Kategorie berechnen.
# - Durchschnittswerte in einem Balkendiagramm darstellen, um zu zeigen, welche Videolängen-Kategorie im Durchschnitt die meisten Aufrufe und Likes erhält.
# - nutzt wieder die Bibliothek ``seaborn`` dafür
# - Funktionen **groupby()** und **agg()** helfen euch
# - für die bins darzustellen könnte die pandas-Funktion **cut()** hilfreich sein
# - nutzt subplots

# %%
### hier sollte euer Code stehen
# nimm die gaming daten,                                       gaming_data...
# gruppiere nach TODO,                                      ...groupby('channel')...

view_groups = gaming_data.groupby('channel').mean(numeric_only=True).sort_values

# füge dem Dataframe gaming_date eine neue Spalte hinzu, mit namen "duration_in_min"
# die spalte soll mit der dauer in minuten gefüllt sein, also erstmal die vorhandene duration von sec in min umrechen
gaming_data.assign(duration_in_min = lambda x:x.duration/60)

# bestimme die dauer des längsten videos
max_duration=gaming_data.duration_in_min.max()
#print(max_duration)

# benutze die maximale dauer um die 5-min Intervalle zu bilden
# herzlichen danke an diese bekloppte sprache dass ich trotzdem selber noch die Umwandlung in Integer vornehmen muss...
durationIntervals = range(0 ,np.ceil(max_duration).astype(int)+5 , 5 )

#print(durationIntervals)

# füge dem Dataframe gaming_data eine spalte hinzu mit dem Intervall der video länge
gaming_data['duration_class']= pd.cut(x=gaming_data.duration_in_min,bins=durationIntervals)

# Definiere eine Aggregat-Funktion, wende sie aber noch nicht an,auf der spalte views_cleaned und mittelwert.
videoDurchschnittAgg = pd.NamedAgg(column='views_cleaned',aggfunc="mean")

# Erzeuge eine neue DataSeries as dem Dataframe
# Gruppiere nach den Duration Klasses, 
# wende auf die spalte views_cleand die Mittelwertbildung an, 
# sortiere die Datenserie nach den Duration_classes aufsteigen (kruze videos zu erste.)
videos_per_duration = gaming_data.groupby('duration_class').agg(meanViews=videoDurchschnittAgg).sort_values(by='duration_class',ascending=True)

# leere Zeilen fallen lassen
videos_per_duration = videos_per_duration.dropna() 

#print(videos_per_duration)

# weil seaborn dumm ist wie huntermeter feldweg, muss man die Kategorien nochmal überarbeiten
intvals=[]
for cat in videos_per_duration.index:
    z=""+str(cat.left)+" - "+str(cat.right)+" min" #join(cat.left," - ",cat.right," min")
    intvals.append(z)

#print(intvals)

sns.set(rc={'figure.figsize':(11,8)}) # Definiere die Größe des Diagramms.

# Dumm wie huntermeter feldweg...
#sns.barplot(x=videos_per_duration.index,y=videos_per_duration.meanViews,palette="viridis") # Erzeuge das Diagramm
ax = sns.barplot(x=intvals,y=videos_per_duration.meanViews,palette="viridis")# Erzeuge das Diagramm
ax.set_title('Durchschnittliche Ansichte je Video-Dauer') 
ax.set_xlabel('Videodauer in min')
ax.set_ylabel('Durchschnittliche Ansichten')
plt.xticks(rotation=90) # Achsenbeschriftung drehen 
plt.ticklabel_format(axis='y',style='plain') # die AchenBeschriftung in 'normalerweise' langer darstellung ausschreiben
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21080\1849646093.py in ?()
#       8 # die spalte soll mit der dauer in minuten gefüllt sein, also erstmal die vorhandene duration von sec in min umrechen
#       9 gaming_data.assign(duration_in_min = lambda x:x.duration/60)
#      10
#      11 # bestimme die dauer des längsten videos
# ---> 12 max_duration=gaming_data.duration_in_min.max()
#      13 #print(max_duration)
#      14
#      15 # benutze die maximale dauer um die 5-min Intervalle zu bilden
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duration_in_min'

# %%
### hier nichts ausführen, sonst verschwindet der Output.

# %% [markdown]
# ### Analyse
# <span style="color:red">
# **Schreibt den eine kurze Analyse und Interpretation der Plots. **
# </span>

# %% [markdown]
# ### Analyse:
#
# - Anhand dieses Ergebnisses könnte man annehen, dass es einen "Sweet Spot" bei der Dauer gibt.
# - Videos im Bereich einer guten halben bis Dreiviertelstunde scheinen beliebt. Sonst fällt die Like-Zahl stark ab.
# - Videos mit sehr kurzer Dauer (<= 5min) scheinen von diesem Abfall nicht so stark betroffen.

# %% [markdown]
# ### 4. Wie schnell landet ein Video in den Trends
# - nun Wollen wir uns ansehen, welche Kanäle es am schnellsten in die Trends geschafft haben:
#
# - Verwendet hierfür auch seaborn
# - plottet ein Histogramm mit 'hours_until_trend'
# - Erstellt eine Tabelle die eine sortierte Liste mit den Kanälen ausgibt

# %%
### hier sollte euer Code stehen

# %%
### hier nichts ausführen, sonst verschwindet der Output.
# Out:
#                                                   title      channel  \
# 2097  Battlefield 2042 Official Reveal Trailer (ft. ...  Battlefield
# 4968                                    where I've been  Technoblade
# 3683  Minecraft, But Item Drops Are Random And Multi...       Sapnap
# 5955                "Final Waltz" | Dream SMP Animation      SAD-ist
# 5574                            The Visitor [Dream SMP]  Technoblade
#
#       hours_until_trend
# 2097           4.330278
# 4968           4.734444
# 3683           4.909444
# 5955           5.065000
# 5574           5.316111

# %% [markdown]
# ### Analyse
# <span style="color:red">
# **Schreibt den eine kurze Analyse und Interpretation der Plots. **
# </span>

# %% [markdown]
# ### Analyse:
#
# - hier ist Platz für euren Text.

# %% [markdown]
# ### 5. Wochentag
# Lasst uns den Veröffentlichungstag der Woche analysieren, um zu sehen, ob es bestimmte Tage gibt, an denen Videos tendenziell beliebter sind.
#
# Wir gehen wie folgt vor:
# - Wochentag aus dem Veröffentlichungsdatum extrahieren.
# - durchschnittliche Anzahl von Aufrufen und Likes für jeden Wochentag berechnen.
# - die erhaltenen Durchschnittswerte in einem Balkendiagramm darstellen, um zu zeigen, welche Wochentage im Durchschnitt die meisten Aufrufe und Likes erhalten.
# - der Code der vorherigen Aufgaben wird euch hier eine goße Hilfe sein.
# <span style="color:red">
# **Schreibt den code dafür. **
# </span>

# %%
### code goes here :D

# %%
### hier nichts ausführen, sonst verschwindet der Output.

# %% [markdown]
# ### Analyse
# <span style="color:red">
# **Schreibt den eine kurze Analyse und Interpretation der Plots. **
# </span>

# %% [markdown]
# ### Analyse:
#
# - hier ist Platz für euren Text.

# %% [markdown]
# ## Zusatzaufgabe zu Korrelationen (optional)
# - Lies dir durch, was Korrelationen sind
# - welche Algorithmen (Korrelationskoeffizienten) es gibt
# - welche Voraussetzungen diese benötigen
# - wie man sie mit python anwenden kann
#
# Hinweis: das macht die nächste Praktikumsaufgabe leichter zu bewältigen
